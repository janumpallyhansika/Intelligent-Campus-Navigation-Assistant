# %%
import pandas as pd

campus_data = {

"Location": [

"Main Gate",
"Library",
"CSE Block",
"ECE Block",
"Mechanical Block",
"Civil Block",
"Admin Office",
"Cafeteria",
"Hostel A",
"Hostel B",
"Auditorium",
"Sports Complex",
"Medical Center",
"Parking Area",
"Exam Cell",
"Placement Cell",
"Seminar Hall",
"Research Center",
"Bus Stop",
"Student Center"

],

"Latitude": [

13.0820,
13.0827,
13.0835,
13.0840,
13.0845,
13.0850,
13.0855,
13.0822,
13.0830,
13.0838,
13.0848,
13.0858,
13.0862,
13.0815,
13.0842,
13.0853,
13.0846,
13.0865,
13.0818,
13.0833

],

"Longitude": [

80.2700,
80.2707,
80.2715,
80.2720,
80.2728,
80.2735,
80.2740,
80.2725,
80.2730,
80.2738,
80.2745,
80.2750,
80.2755,
80.2698,
80.2742,
80.2748,
80.2739,
80.2760,
80.2705,
80.2729

]

}

df = pd.DataFrame(campus_data)

df.to_csv(
    "campus_dataset.csv",
    index=False
)

print(df)
# Out:
#             Location  Latitude  Longitude
# 0          Main Gate   13.0820    80.2700
# 1            Library   13.0827    80.2707
# 2          CSE Block   13.0835    80.2715
# 3          ECE Block   13.0840    80.2720
# 4   Mechanical Block   13.0845    80.2728
# 5        Civil Block   13.0850    80.2735
# 6       Admin Office   13.0855    80.2740
# 7          Cafeteria   13.0822    80.2725
# 8           Hostel A   13.0830    80.2730
# 9           Hostel B   13.0838    80.2738
# 10        Auditorium   13.0848    80.2745
# 11    Sports Complex   13.0858    80.2750
# 12    Medical Center   13.0862    80.2755
# 13      Parking Area   13.0815    80.2698
# 14         Exam Cell   13.0842    80.2742
# 15    Placement Cell   13.0853    80.2748
# 16      Seminar Hall   13.0846    80.2739
# 17   Research Center   13.0865    80.2760
# 18          Bus Stop   13.0818    80.2705
# 19    Student Center   13.0833    80.2729
